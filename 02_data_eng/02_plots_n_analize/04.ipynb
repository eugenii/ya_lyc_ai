# %% [markdown]
# #### 4 Качество фильмов самого плодотворного режиссёра

# %%
# Импорт библиотек
import pandas as pd

# %%
# Импорт данных
df = pd.read_csv('../kinopoisk-top250.csv')

# %%
# Разделяем режиссёров на отдельные строки
directors_all = df['director'].str.split('; ', expand=True)
display(directors_all.head(15))
# Out:
#                         0               1    2
# 0          Фрэнк Дарабонт             NaN  NaN
# 1          Фрэнк Дарабонт             NaN  NaN
# 2          Роберт Земекис             NaN  NaN
# 3         Стивен Спилберг             NaN  NaN
# 4            Оливье Накаш   Эрик Толедано  NaN
# 5         Кристофер Нолан             NaN  NaN
# 6              Люк Бессон             NaN  NaN
# 7           Роджер Аллерс     Роб Минкофф  NaN
# 8            Дэвид Финчер             NaN  NaN
# 9           Леонид Гайдай             NaN  NaN
# 10        Роберто Бениньи             NaN  NaN
# 11               Томас Ян             NaN  NaN
# 12   Фрэнсис Форд Коппола             NaN  NaN
# 13      Квентин Тарантино             NaN  NaN
# 14          Леонид Гайдай             NaN  NaN
