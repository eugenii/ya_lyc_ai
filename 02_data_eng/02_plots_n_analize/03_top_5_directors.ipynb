# %% [markdown]
# ### Топ-5 режиссёров

# %%
# Импорт библиотек

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Импорт данных

df = pd.read_csv('../kinopoisk-top250.csv')

# %%
# Подсчитываем количество фильмов у режиссёров

director_counts = df['director'].value_counts()

# Выбираем топ режиссеров
top_directors = director_counts.head(10)

# Выводим результат
print(top_directors, type(top_directors))

for director in top_directors.index:
    print(director.split()[-1], end=',')
# Out:
# director
# Игорь Масленников    7
# Роберт Земекис       5
# Леонид Гайдай        5
# Кристофер Нолан      5
# Дэвид Финчер         5
# Стивен Спилберг      5
# Питер Джексон        5
# Чарльз Чаплин        5
# Гай Ричи             4
# Мартин Скорсезе      4
# Name: count, dtype: int64 <class 'pandas.core.series.Series'>
# Масленников
# Земекис
# Гайдай
# Нолан
# Финчер
# Спилберг
# Джексон
# Чаплин
# Ричи
# Скорсезе

# %%
# # Разделяем режиссёров на отдельные строки
# df['directors_all'] = df['director'].str.split('; ', expand=True).stack()
# display(directors)
# # Считаем количество фильмов для каждого режиссёра
# director_counts = directors.value_counts()

# # Берём топ-5 режиссёров 
# # top_directors = director_counts.head(5)

# # # Выделяем фамилию
# # directors_split = top_directors.str.split().str[-1]



# # display(top_directors, type(top_directors))

# # # # Извлекаем индексы (фамилии) и объединяем их через запятую
# # result = ','.join(top_directors.index.str.strip())  # Убираем лишние пробелы

# # # # Выводим результат
# # print(result)
